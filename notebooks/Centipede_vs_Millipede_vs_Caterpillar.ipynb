# %%
#hide
! [ -e /content ] && pip install -Uqq fastbook timm
import fastbook
fastbook.setup_book()

# %%
import timm
from fastai.vision.all import *
from fastai.vision.widgets import *
from fastbook import search_images_ddg

# %% [markdown]
# # Getting the data

# %%
insects = ['millipede', 'centipede', 'caterpillar']
path = Path('insects')

# %%
if not path.exists():
    path.mkdir()
    for insect in insects:
        dest = (path/insect)
        dest.mkdir(exist_ok=True)
        urls = search_images_ddg(f'{insect}')
        download_images(urls=urls, dest=dest)

# %%
path.ls()
# Out:
# (#3) [Path('insects/centipede'),Path('insects/millipede'),Path('insects/caterpillar')]

# %%
sample = (path/'millipede').ls()[0]
im = Image.open(sample)
im.to_thumb(224, 224)
# Out:
# <PIL.Image.Image image mode=RGB size=224x149>

# %%
sample = (path/'centipede').ls()[0]
im = Image.open(sample)
im.to_thumb(224, 224)
# Out:
# <PIL.Image.Image image mode=RGB size=224x149>

# %%
sample = (path/'caterpillar').ls()[0]
im = Image.open(sample)
im.to_thumb(224, 224)
# Out:
# <PIL.Image.Image image mode=RGB size=169x224>

# %%
for insect in insects:
    print(f'insect: {insect}, number: {len((path/insect).ls())}')
# Out:
# insect: millipede, number: 184
# insect: centipede, number: 192
# insect: caterpillar, number: 189

# %%
fns = get_image_files(path)
failed = verify_images(fns)
failed
# Out:
# (#0) []

# %%
failed.map(Path.unlink);

# %% [markdown]
# # Creating a Baseline

# %%
dblock = DataBlock(
            blocks=(ImageBlock, CategoryBlock),
            get_items=get_image_files,
            get_y=parent_label,
            splitter=RandomSplitter(seed=42),
            item_tfms=RandomResizedCrop(224, min_scale=0.5))

# %%
dblock.summary(path)
# Out:
# Setting-up type transforms pipelines
# Collecting items from insects
# Found 561 items
# 2 datasets of sizes 449,112
# Setting up Pipeline: PILBase.create
# Setting up Pipeline: parent_label -> Categorize -- {'vocab': None, 'sort': True, 'add_na': False}
#
# Building one sample
#   Pipeline: PILBase.create
#     starting from
#       insects/millipede/53fc239f-c11b-4c92-9ad0-915957674f0d.jpg
#     applying PILBase.create gives
#       PILImage mode=RGB size=1280x850
#   Pipeline: parent_label -> Categorize -- {'vocab': None, 'sort': True, 'add_na': False}
#     starting from
#       insects/millipede/53fc239f-c11b-4c92-9ad0-915957674f0d.jpg
#     applying parent_label gives
#       millipede
#     applying Categorize -- {'vocab': None, 'sort': True, 'add_na': False} gives
#       TensorCategory(2)
#
# Final sample: (PILImage mode=RGB size=1280x850, TensorCategory(2))
#
#
# Collecting items from insects
# Found 561 items
# 2 datasets of sizes 449,112
# Setting up Pipeline: PILBase.create
# Setting up Pipeline: parent_label -> Categorize -- {'vocab': None, 'sort': True, 'add_na': False}
# Setting up after_item: Pipeline: RandomResizedCrop -- {'size': (224, 224), 'min_scale': 0.5, 'ratio': (0.75, 1.3333333333333333), 'resamples': (<Resampling.BILINEAR: 2>, <Resampling.NEAREST: 0>), 'val_xtra': 0.14, 'max_scale': 1.0, 'p': 1.0} -> ToTensor
# Setting up before_batch: Pipeline:
# Setting up after_batch: Pipeline: IntToFloatTensor -- {'div': 255.0, 'div_mask': 1}
#
# Building one batch
# Applying item_tfms to the first sample:
#   Pipeline: RandomResizedCrop -- {'size': (224, 224), 'min_scale': 0.5, 'ratio': (0.75, 1.3333333333333333), 'resamples': (<Resampling.BILINEAR: 2>, <Resampling.NEAREST: 0>), 'val_xtra': 0.14, 'max_scale': 1.0, 'p': 1.0} -> ToTensor
#     starting from
#       (PILImage mode=RGB size=1280x850, TensorCategory(2))
#     applying RandomResizedCrop -- {'size': (224, 224), 'min_scale': 0.5, 'ratio': (0.75, 1.3333333333333333), 'resamples': (<Resampling.BILINEAR: 2>, <Resampling.NEAREST: 0>), 'val_xtra': 0.14, 'max_scale': 1.0, 'p': 1.0} gives
#       (PILImage mode=RGB size=224x224, TensorCategory(2))
#     applying ToTensor gives
#       (TensorImage of size 3x224x224, TensorCategory(2))
#
# Adding the next 3 samples
#
# No before_batch transform to apply
#
# Collating items in a batch
#
# Applying batch_tfms to the batch built
#   Pipeline: IntToFloatTensor -- {'div': 255.0, 'div_mask': 1}
#     starting from
#       (TensorImage of size 4x3x224x224, TensorCategory([2, 2, 2, 1], device='cuda:0'))
#     applying IntToFloatTensor -- {'div': 255.0, 'div_mask': 1} gives
#       (TensorImage of size 4x3x224x224, TensorCategory([2, 2, 2, 1], device='cuda:0'))

# %%
dls = dblock.dataloaders(path)

# %%
dls.train.show_batch()

# %%
learn = vision_learner(dls, arch=resnet18, pretrained=False, loss_func=CrossEntropyLossFlat(), metrics=accuracy)

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0003311311302240938)

# %%
learn.fit(10, lr=3e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.629990</td>
#       <td>1.308899</td>
#       <td>0.571429</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.647125</td>
#       <td>1.201464</td>
#       <td>0.598214</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.617324</td>
#       <td>1.020347</td>
#       <td>0.589286</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.586604</td>
#       <td>1.047875</td>
#       <td>0.633929</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.590294</td>
#       <td>1.179428</td>
#       <td>0.598214</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.578183</td>
#       <td>1.041951</td>
#       <td>0.571429</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.564578</td>
#       <td>1.063394</td>
#       <td>0.660714</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.539564</td>
#       <td>1.087738</td>
#       <td>0.589286</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.541352</td>
#       <td>1.075677</td>
#       <td>0.633929</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.534757</td>
#       <td>1.160585</td>
#       <td>0.651786</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Improving the Model

# %% [markdown]
# ## a) Cleaning the data

# %%
interp = ClassificationInterpretation.from_learner(learn)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.plot_top_losses(k=6, nrows=3, figsize=(10,10))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# VBox(children=(Dropdown(options=('caterpillar', 'centipede', 'millipede'), value='caterpillar'), Dropdown(opti…

# %%
for idx in cleaner.delete(): cleaner.fns[idx].unlink()
for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)

# %%
dls = dblock.dataloaders(path)

# %%
learn = vision_learner(dls, arch=resnet18, pretrained=False, loss_func=CrossEntropyLossFlat(), metrics=accuracy)
learn.fit(10, lr=3e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.959085</td>
#       <td>417.480164</td>
#       <td>0.357143</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.501169</td>
#       <td>125.615318</td>
#       <td>0.357143</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.314491</td>
#       <td>17.856888</td>
#       <td>0.357143</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.161941</td>
#       <td>3.423977</td>
#       <td>0.464286</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.068379</td>
#       <td>1.590003</td>
#       <td>0.517857</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.001137</td>
#       <td>3.260970</td>
#       <td>0.508929</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.938896</td>
#       <td>1.513425</td>
#       <td>0.553571</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.885058</td>
#       <td>1.276793</td>
#       <td>0.633929</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.841374</td>
#       <td>1.326213</td>
#       <td>0.589286</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.804490</td>
#       <td>1.017544</td>
#       <td>0.589286</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## b) Pretrained Model

# %%
learn = vision_learner(dls, arch=resnet18, pretrained=True, loss_func=CrossEntropyLossFlat(), metrics=accuracy)

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0008317637839354575)

# %%
learn.fit(10, lr=3e-2)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.493397</td>
#       <td>5.979974</td>
#       <td>0.553571</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.133341</td>
#       <td>17.029814</td>
#       <td>0.482143</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.037795</td>
#       <td>4.181496</td>
#       <td>0.651786</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.916816</td>
#       <td>1.470768</td>
#       <td>0.776786</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.899479</td>
#       <td>2.682775</td>
#       <td>0.714286</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.854410</td>
#       <td>1.374917</td>
#       <td>0.830357</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.765372</td>
#       <td>1.089912</td>
#       <td>0.848214</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.698313</td>
#       <td>1.414372</td>
#       <td>0.785714</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.620235</td>
#       <td>2.899143</td>
#       <td>0.705357</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.552140</td>
#       <td>1.662160</td>
#       <td>0.794643</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## c) Augmentations

# %%
dblock = DataBlock(
            blocks=(ImageBlock, CategoryBlock),
            get_items=get_image_files,
            get_y=parent_label,
            splitter=RandomSplitter(seed=42),
            item_tfms=RandomResizedCrop(224, min_scale=0.5),
            batch_tfms=aug_transforms())

# %%
dls = dblock.dataloaders(path)

# %%
learn = vision_learner(dls, arch=resnet18, pretrained=True, loss_func=CrossEntropyLossFlat(), metrics=accuracy)

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0012022644514217973)

# %%
learn.fit(10, lr=1e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.040078</td>
#       <td>0.998627</td>
#       <td>0.750000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.715323</td>
#       <td>0.553207</td>
#       <td>0.848214</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.555363</td>
#       <td>0.419837</td>
#       <td>0.901786</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.445000</td>
#       <td>0.413472</td>
#       <td>0.892857</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.376438</td>
#       <td>0.437765</td>
#       <td>0.848214</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.321526</td>
#       <td>0.443171</td>
#       <td>0.875000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.281951</td>
#       <td>0.449143</td>
#       <td>0.875000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.247060</td>
#       <td>0.431489</td>
#       <td>0.875000</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.217692</td>
#       <td>0.415946</td>
#       <td>0.883929</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.195850</td>
#       <td>0.435383</td>
#       <td>0.892857</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## d) Learning Rate Scheduling

# %%
learn = vision_learner(dls, arch=resnet18, pretrained=True, loss_func=CrossEntropyLossFlat(), metrics=accuracy)

# %%
learn.fit_one_cycle(10, 1e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.993002</td>
#       <td>1.045324</td>
#       <td>0.544643</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.447800</td>
#       <td>0.496457</td>
#       <td>0.785714</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.050055</td>
#       <td>0.471426</td>
#       <td>0.848214</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.835623</td>
#       <td>0.453243</td>
#       <td>0.883929</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.676756</td>
#       <td>0.435658</td>
#       <td>0.892857</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.564385</td>
#       <td>0.420974</td>
#       <td>0.901786</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.491622</td>
#       <td>0.412781</td>
#       <td>0.901786</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.428168</td>
#       <td>0.412300</td>
#       <td>0.901786</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.388304</td>
#       <td>0.411616</td>
#       <td>0.901786</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.350503</td>
#       <td>0.420127</td>
#       <td>0.901786</td>
#       <td>00:06</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## e) Different Models

# %% [markdown]
# https://www.kaggle.com/code/jhoward/the-best-vision-models-for-fine-tuning

# %%
learn = vision_learner(dls, arch=resnet34, pretrained=True, loss_func=CrossEntropyLossFlat(), metrics=accuracy)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-b627a593.pth" to /root/.cache/torch/hub/checkpoints/resnet34-b627a593.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0010000000474974513)

# %%
learn.fit_one_cycle(10, 1e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.510600</td>
#       <td>1.348115</td>
#       <td>0.571429</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.187363</td>
#       <td>0.517703</td>
#       <td>0.830357</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.855175</td>
#       <td>0.456228</td>
#       <td>0.857143</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.670456</td>
#       <td>0.421848</td>
#       <td>0.857143</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.545408</td>
#       <td>0.390719</td>
#       <td>0.839286</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.456536</td>
#       <td>0.366798</td>
#       <td>0.839286</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.391424</td>
#       <td>0.360532</td>
#       <td>0.839286</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.339794</td>
#       <td>0.359607</td>
#       <td>0.839286</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.302976</td>
#       <td>0.350605</td>
#       <td>0.848214</td>
#       <td>00:07</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.270209</td>
#       <td>0.339054</td>
#       <td>0.848214</td>
#       <td>00:07</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = vision_learner(dls, arch='convnext_tiny_in22k', pretrained=True, loss_func=CrossEntropyLossFlat(), metrics=accuracy)
# Out:
# Downloading: "https://dl.fbaipublicfiles.com/convnext/convnext_tiny_22k_224.pth" to /root/.cache/torch/hub/checkpoints/convnext_tiny_22k_224.pth

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# SuggestedLRs(valley=0.0006918309954926372)

# %%
learn.fit_one_cycle(10, 1e-3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.764455</td>
#       <td>1.089494</td>
#       <td>0.562500</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.083835</td>
#       <td>0.341217</td>
#       <td>0.892857</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.784708</td>
#       <td>0.200004</td>
#       <td>0.946429</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.597272</td>
#       <td>0.151468</td>
#       <td>0.955357</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.477258</td>
#       <td>0.155412</td>
#       <td>0.955357</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.384791</td>
#       <td>0.169215</td>
#       <td>0.946429</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.323914</td>
#       <td>0.173487</td>
#       <td>0.946429</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.273584</td>
#       <td>0.172082</td>
#       <td>0.946429</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.237643</td>
#       <td>0.165515</td>
#       <td>0.946429</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.210010</td>
#       <td>0.164638</td>
#       <td>0.946429</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.export()

# %% [markdown]
# # Pushing to huggingface for usage later.

# %%
# !pip install -Uqq huggingface_hub["fastai"]

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
